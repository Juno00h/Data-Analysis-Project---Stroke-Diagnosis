# %% [markdown]
# ---
# ## <div align="center">Exploratory Data Analysis & Visualization</div>

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import pylab as pl
from sklearn import metrics
import scipy.optimize as opt
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Read & Load the Dataset

# %%
data = pd.read_csv('healthcare-dataset-stroke-data.csv')
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
sns.heatmap(data.isnull(), cbar=False, cmap="YlGnBu_r")
sns.set(rc = {'figure.figsize':(20,8)})
plt.title('Missing Data')
plt.show()

# %% [markdown]
# ---
# ## <div align="center">VISUALIZATION</div>

# %% [markdown]
# ### DATA BINNING

# %%
#AGE RANGE
import numpy as np
data['AGE_RANGE'] = np.where (
    data['age'] <= 10, 'Gen Alpha', 
    np.where(data['age'] <= 26,'Gen Z', 
             np.where(data['age'] <= 42, 'Millennials',
                      np.where(data['age'] <=58, 'Gen X',
                              np.where(data['age'] <= 77, 'Baby Boomers', 'The Silent Generation')))))
data #Show the Table
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke              AGE_RANGE
# 0          1           Baby Boomers
# 1          1           Baby Boomers
# 2          1  The Silent Generation
# 3          1                  Gen X
# 4          1  The Silent Generation
# ...      ...                    ...
# 5105       0  The Silent Generation
# 5106       0  The Silent Generation
# 5107       0            Millennials
# 5108       0                  Gen X
# 5109       0                  Gen X
#
# [5110 rows x 13 columns]

# %%
#BMI RANGE
import numpy as np
data['BMI_RANGE']= np.where(
    data['bmi'] <18.5, 'Underweight',
    np.where(data['bmi'] <25, 'normal',
            np.where(data['bmi'] <30, 'overweight', 'obesity')))
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke              AGE_RANGE   BMI_RANGE
# 0          1           Baby Boomers     obesity
# 1          1           Baby Boomers     obesity
# 2          1  The Silent Generation     obesity
# 3          1                  Gen X     obesity
# 4          1  The Silent Generation      normal
# ...      ...                    ...         ...
# 5105       0  The Silent Generation     obesity
# 5106       0  The Silent Generation     obesity
# 5107       0            Millennials     obesity
# 5108       0                  Gen X  overweight
# 5109       0                  Gen X  overweight
#
# [5110 rows x 14 columns]

# %%
# GLUCOSE AVERANGE LEVEL
import numpy as np
data['AVG_GLUCOSE'] = np.where (
    data['avg_glucose_level'] < 55, 'Very Low', 
    np.where(data['avg_glucose_level'] < 70,'Low', 
             np.where(data['avg_glucose_level'] < 181, 'In Target Range',
                      np.where(data['avg_glucose_level'] < 250, 'High','Very High'))))
data #Show the Table
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke              AGE_RANGE   BMI_RANGE      AVG_GLUCOSE
# 0          1           Baby Boomers     obesity             High
# 1          1           Baby Boomers     obesity             High
# 2          1  The Silent Generation     obesity  In Target Range
# 3          1                  Gen X     obesity  In Target Range
# 4          1  The Silent Generation      normal  In Target Range
# ...      ...                    ...         ...              ...
# 5105       0  The Silent Generation     obesity  In Target Range
# 5106       0  The Silent Generation     obesity  In Target Range
# 5107       0            Millennials     obesity  In Target Range
# 5108       0                  Gen X  overweight  In Target Range
# 5109       0                  Gen X  overweight  In Target Range
#
# [5110 rows x 15 columns]

# %%
#HYPERTENSION
data['HYPER'] = np.where(
    data['hypertension'] ==  0, 'Doesnt Hypertension', 'Hypertension')
data #Show the Table
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke              AGE_RANGE   BMI_RANGE      AVG_GLUCOSE  \
# 0          1           Baby Boomers     obesity             High
# 1          1           Baby Boomers     obesity             High
# 2          1  The Silent Generation     obesity  In Target Range
# 3          1                  Gen X     obesity  In Target Range
# 4          1  The Silent Generation      normal  In Target Range
# ...      ...                    ...         ...              ...
# 5105       0  The Silent Generation     obesity  In Target Range
# 5106       0  The Silent Generation     obesity  In Target Range
# 5107       0            Millennials     obesity  In Target Range
# 5108       0                  Gen X  overweight  In Target Range
# 5109       0                  Gen X  overweight  In Target Range
#
#                     HYPER
# 0     Doesnt Hypertension
# 1     Doesnt Hypertension
# 2     Doesnt Hypertension
# 3     Doesnt Hypertension
# 4            Hypertension
# ...                   ...
# 5105         Hypertension
# 5106  Doesnt Hypertension
# 5107  Doesnt Hypertension
# 5108  Doesnt Hypertension
# 5109  Doesnt Hypertension
#
# [5110 rows x 16 columns]

# %%
#HEART DISEASE
data['HEART'] = np.where(
    data['heart_disease'] ==  0, 'Doesnt Heart Disease', 'Heart Disease')
data #Show the Table
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke              AGE_RANGE   BMI_RANGE      AVG_GLUCOSE  \
# 0          1           Baby Boomers     obesity             High
# 1          1           Baby Boomers     obesity             High
# 2          1  The Silent Generation     obesity  In Target Range
# 3          1                  Gen X     obesity  In Target Range
# 4          1  The Silent Generation      normal  In Target Range
# ...      ...                    ...         ...              ...
# 5105       0  The Silent Generation     obesity  In Target Range
# 5106       0  The Silent Generation     obesity  In Target Range
# 5107       0            Millennials     obesity  In Target Range
# 5108       0                  Gen X  overweight  In Target Range
# 5109       0                  Gen X  overweight  In Target Range
#
#                     HYPER                 HEART
# 0     Doesnt Hypertension         Heart Disease
# 1     Doesnt Hypertension  Doesnt Heart Disease
# 2     Doesnt Hypertension         Heart Disease
# 3     Doesnt Hypertension  Doesnt Heart Disease
# 4            Hypertension  Doesnt Heart Disease
# ...                   ...                   ...
# 5105         Hypertension  Doesnt Heart Disease
# 5106  Doesnt Hypertension  Doesnt Heart Disease
# 5107  Doesnt Hypertension  Doesnt Heart Disease
# 5108  Doesnt Hypertension  Doesnt Heart Disease
# 5109  Doesnt Hypertension  Doesnt Heart Disease
#
# [5110 rows x 17 columns]

# %%
#STROKE
data['STROKE'] = np.where(
    data['stroke'] ==  0, 'Not Stroke', 'Stroke')
data #Show the Table
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke              AGE_RANGE   BMI_RANGE      AVG_GLUCOSE  \
# 0          1           Baby Boomers     obesity             High
# 1          1           Baby Boomers     obesity             High
# 2          1  The Silent Generation     obesity  In Target Range
# 3          1                  Gen X     obesity  In Target Range
# 4          1  The Silent Generation      normal  In Target Range
# ...      ...                    ...         ...              ...
# 5105       0  The Silent Generation     obesity  In Target Range
# 5106       0  The Silent Generation     obesity  In Target Range
# 5107       0            Millennials     obesity  In Target Range
# 5108       0                  Gen X  overweight  In Target Range
# 5109       0                  Gen X  overweight  In Target Range
#
#                     HYPER                 HEART      STROKE
# 0     Doesnt Hypertension         Heart Disease      Stroke
# 1     Doesnt Hypertension  Doesnt Heart Disease      Stroke
# 2     Doesnt Hypertension         Heart Disease      Stroke
# 3     Doesnt Hypertension  Doesnt Heart Disease      Stroke
# 4            Hypertension  Doesnt Heart Disease      Stroke
# ...                   ...                   ...         ...
# 5105         Hypertension  Doesnt Heart Disease  Not Stroke
# 5106  Doesnt Hypertension  Doesnt Heart Disease  Not Stroke
# 5107  Doesnt Hypertension  Doesnt Heart Disease  Not Stroke
# 5108  Doesnt Hypertension  Doesnt Heart Disease  Not Stroke
# 5109  Doesnt Hypertension  Doesnt Heart Disease  Not Stroke
#
# [5110 rows x 18 columns]

# %%
data.rename(columns={'AGE_glucose': 'AVG_GLUCOSE'}, inplace=True)

# %%
data.rename(columns={'gender': 'GENDER'}, inplace=True)

# %%
my_data_crea = data[['GENDER', 'AGE_RANGE', 'BMI_RANGE', 'AVG_GLUCOSE','HYPER','HEART', 'ever_married' ,'work_type', 'Residence_type', 'smoking_status', 'STROKE']]
my_data_crea
# Out:
#       GENDER              AGE_RANGE   BMI_RANGE      AVG_GLUCOSE  \
# 0       Male           Baby Boomers     obesity             High
# 1     Female           Baby Boomers     obesity             High
# 2       Male  The Silent Generation     obesity  In Target Range
# 3     Female                  Gen X     obesity  In Target Range
# 4     Female  The Silent Generation      normal  In Target Range
# ...      ...                    ...         ...              ...
# 5105  Female  The Silent Generation     obesity  In Target Range
# 5106  Female  The Silent Generation     obesity  In Target Range
# 5107  Female            Millennials     obesity  In Target Range
# 5108    Male                  Gen X  overweight  In Target Range
# 5109  Female                  Gen X  overweight  In Target Range
#
#                     HYPER                 HEART ever_married      work_type  \
# 0     Doesnt Hypertension         Heart Disease          Yes        Private
# 1     Doesnt Hypertension  Doesnt Heart Disease          Yes  Self-employed
# 2     Doesnt Hypertension         Heart Disease          Yes        Private
# 3     Doesnt Hypertension  Doesnt Heart Disease          Yes        Private
# 4            Hypertension  Doesnt Heart Disease          Yes  Self-employed
# ...                   ...                   ...          ...            ...
# 5105         Hypertension  Doesnt Heart Disease          Yes        Private
# 5106  Doesnt Hypertension  Doesnt Heart Disease          Yes  Self-employed
# 5107  Doesnt Hypertension  Doesnt Heart Disease          Yes  Self-employed
# 5108  Doesnt Hypertension  Doesnt Heart Disease          Yes        Private
# 5109  Doesnt Hypertension  Doesnt Heart Disease          Yes       Govt_job
#
#      Residence_type   smoking_status      STROKE
# 0             Urban  formerly smoked      Stroke
# 1             Rural     never smoked      Stroke
# 2             Rural     never smoked      Stroke
# 3             Urban           smokes      Stroke
# 4             Rural     never smoked      Stroke
# ...             ...              ...         ...
# 5105          Urban     never smoked  Not Stroke
# 5106          Urban     never smoked  Not Stroke
# 5107          Rural     never smoked  Not Stroke
# 5108          Rural  formerly smoked  Not Stroke
# 5109          Urban          Unknown  Not Stroke
#
# [5110 rows x 11 columns]

# %% [markdown]
# ## PIE CHART

# %%
# Focus by using 'Age' Coloumn by group of AGE_RANGE
AGE_RANGE_PIE = data.groupby('AGE_RANGE')['age'].sum()

# Plotting Age by Range
AGE_RANGE_PIE.plot.pie(subplots=True, autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Age by Range')
plt.legend(AGE_RANGE_PIE.index, loc="lower left", title='Range (Generation)')
plt.show()

# %% [markdown]
# # BARCHART

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Set the style of the visualization
sns.set(style="whitegrid")

# %%
visualization_data = my_data_crea.apply(lambda x: pd.Series(x.value_counts(normalize=True))).T

# %%
# Plot the stacked bar chart
plt.figure(figsize=(12, 8))
ax = visualization_data.plot(kind="bar", stacked=True, colormap="viridis")

# Customize the plot
plt.title("Distribution of Responses for Each Category", fontweight='bold', fontsize=16)  # Make title bold and larger
plt.xlabel("Coloumn")
plt.ylabel("Percentage")
plt.legend(title="Response", bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %% [markdown]
# # 3D

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
# Assuming df is your DataFrame
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot for stroke = 1
ax.scatter(data[data["stroke"] == 1]['age'][:1000],
           data[data["stroke"] == 1]['avg_glucose_level'][:900],
           data[data["stroke"] == 1]['bmi'][:900],
           color='DarkBlue', label='Stroke')

# Scatter plot for stroke = 0
ax.scatter(data[data["stroke"] == 0]['age'][:900],
           data[data["stroke"] == 0]['avg_glucose_level'][:900],
           data[data["stroke"] == 0]['bmi'][:900],
           color='Yellow', label='Not Stroke')

# %% [markdown]
# ---
# ## <div align="center">CLEANING RAW DATA</div>

# %% [markdown]
# #### Membuat DataFrame baru untuk variable-variable yang akan digunakan

# %%
data = pd.read_csv('healthcare-dataset-stroke-data.csv')
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
df = data[['gender', 'age', 'hypertension', 'heart_disease',
           'avg_glucose_level', 'bmi', 'smoking_status', 'stroke']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             5110 non-null   object
#  1   age                5110 non-null   float64
#  2   hypertension       5110 non-null   int64
#  3   heart_disease      5110 non-null   int64
#  4   avg_glucose_level  5110 non-null   float64
#  5   bmi                4909 non-null   float64
#  6   smoking_status     5110 non-null   object
#  7   stroke             5110 non-null   int64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 319.5+ KB

# %% [markdown]
# #### Melihat banyaknya unique value pada tiap variable dalam dataset

# %%
df.nunique()
# Out:
# gender                  3
# age                   104
# hypertension            2
# heart_disease           2
# avg_glucose_level    3979
# bmi                   418
# smoking_status          4
# stroke                  2
# dtype: int64

# %% [markdown]
# #### Memvisualisasikan variable dengan dtype categorical dalam dataset

# %%
plt.figure(figsize=(15, 6))
colors = sns.color_palette('pastel')[0:5]
sns.countplot(x='gender', data=df, palette=colors)
plt.title('Gender Distribution')
plt.show()
# Out:
# C:\Users\KENNETH\anaconda3\envs\notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\KENNETH\anaconda3\envs\notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\KENNETH\anaconda3\envs\notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Menghapus data dengan gender Other karena tidak valid

df.drop(df[df['gender'] == 'Other'].index, inplace=True)
# Out:
# C:\Users\KENNETH\AppData\Local\Temp\ipykernel_4488\3885859513.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[df['gender'] == 'Other'].index, inplace=True)

# %%
plt.figure(figsize=(15, 6))
colors = sns.color_palette('pastel')[0:5]
sns.countplot(x='smoking_status', data=df, palette=colors)
plt.title('Smoking Status Distribution')
plt.show()
# Out:
# C:\Users\KENNETH\anaconda3\envs\notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\KENNETH\anaconda3\envs\notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\KENNETH\anaconda3\envs\notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Menghapus data dengan smoking_status Unknown karena tidak valid

df.drop(df[df['smoking_status'] == 'Unknown'].index, inplace=True)
# Out:
# C:\Users\KENNETH\AppData\Local\Temp\ipykernel_4488\2175647561.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[df['smoking_status'] == 'Unknown'].index, inplace=True)

# %% [markdown]
# #### Encoding beberapa variable categorical (gender & smoking_status) ke numeric

# %%
from sklearn.preprocessing import LabelEncoder

cdtype = df[['gender', 'smoking_status']]

le = LabelEncoder()
for var in cdtype:
    df[var] = le.fit_transform(df[var])
    
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3565 entries, 0 to 5108
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             3565 non-null   int32
#  1   age                3565 non-null   float64
#  2   hypertension       3565 non-null   int64
#  3   heart_disease      3565 non-null   int64
#  4   avg_glucose_level  3565 non-null   float64
#  5   bmi                3425 non-null   float64
#  6   smoking_status     3565 non-null   int32
#  7   stroke             3565 non-null   int64
# dtypes: float64(3), int32(2), int64(3)
# memory usage: 222.8 KB
# C:\Users\KENNETH\AppData\Local\Temp\ipykernel_4488\2385587201.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[var] = le.fit_transform(df[var])
# C:\Users\KENNETH\AppData\Local\Temp\ipykernel_4488\2385587201.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[var] = le.fit_transform(df[var])

# %%
df.boxplot()
plt.show()

# %% [markdown]
# #### Cek NaN Values

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# avg_glucose_level      0
# bmi                  140
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# #### Dropping the NaN Values

# %%
df = df.dropna()
df
# Out:
#       gender   age  hypertension  heart_disease  avg_glucose_level   bmi  \
# 0          1  67.0             0              1             228.69  36.6
# 2          1  80.0             0              1             105.92  32.5
# 3          0  49.0             0              0             171.23  34.4
# 4          0  79.0             1              0             174.12  24.0
# 5          1  81.0             0              0             186.21  29.0
# ...      ...   ...           ...            ...                ...   ...
# 5100       1  82.0             1              0              71.97  28.3
# 5102       0  57.0             0              0              77.93  21.7
# 5106       0  81.0             0              0             125.20  40.0
# 5107       0  35.0             0              0              82.99  30.6
# 5108       1  51.0             0              0             166.29  25.6
#
#       smoking_status  stroke
# 0                  0       1
# 2                  1       1
# 3                  2       1
# 4                  1       1
# 5                  0       1
# ...              ...     ...
# 5100               1       0
# 5102               1       0
# 5106               1       0
# 5107               1       0
# 5108               0       0
#
# [3425 rows x 8 columns]

# %% [markdown]
# * Before drop NaN data : 5110 rows × 8 columns
# * After drop NaN Data  : 3425 rows × 8 columns

# %%
sns.heatmap(df.isnull(), cbar=False, cmap="YlGnBu_r")
sns.set(rc = {'figure.figsize':(20,8)})
plt.title('Missing Data')
plt.show()

# %% [markdown]
# #### Melihat korelasi antar variable dengan menvisualisasikan dengan heatmap

# %%
plt.figure(figsize = (19,10))
sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
plt.title('Data Correlation')
# Out:
# Text(0.5, 1.0, 'Data Correlation')

# %% [markdown]
# ---
# ## <div align="center">Pre-processing</div>

# %% [markdown]
# #### Menentukan feature & target variable / class

# %%
X = df[['gender', 'age', 'hypertension', 'heart_disease', 
        'avg_glucose_level', 'bmi', 'smoking_status']].values
X[0:5]
# Out:
# array([[  1.  ,  67.  ,   0.  ,   1.  , 228.69,  36.6 ,   0.  ],
#        [  1.  ,  80.  ,   0.  ,   1.  , 105.92,  32.5 ,   1.  ],
#        [  0.  ,  49.  ,   0.  ,   0.  , 171.23,  34.4 ,   2.  ],
#        [  0.  ,  79.  ,   1.  ,   0.  , 174.12,  24.  ,   1.  ],
#        [  1.  ,  81.  ,   0.  ,   0.  , 186.21,  29.  ,   0.  ]])

# %%
y = df["stroke"]
y[0:5]
# Out:
# 0    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: stroke, dtype: int64

# %% [markdown]
# #### Melihat banyaknya orang yang terkena (1) dan tidak terkena Stroke (0)

# %%
unique_vstroke = df["stroke"].value_counts()
unique_vstroke
# Out:
# stroke
# 0    3245
# 1     180
# Name: count, dtype: int64

# %% [markdown]
# #### Gunakan SMOTE untuk meresampled data supaya label class menjadi lebih balance

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state = 5)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %% [markdown]
# #### Membagi data train dan test

# %%
X_train, X_test,  y_train, y_test = train_test_split(X_resampled ,y_resampled , test_size = 0.2, random_state = 5)
print ('Train set:',X_train.shape, y_train.shape)
print ('Test set:', X_test.shape, y_test.shape)
# Out:
# Train set: (5192, 7) (5192,)
# Test set: (1298, 7) (1298,)

# %% [markdown]
# ---
# ## <div align="center">Modeling & Evaluation</div>

# %%
from sklearn.metrics import classification_report, confusion_matrix, f1_score, jaccard_score
import itertools

# %% [markdown]
# ---
# ### <div align="center">Algorithm Decision Tree</div>

# %% [markdown]
# #### Modeling

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
strokeTree = DecisionTreeClassifier(criterion="entropy", max_depth = 5)
strokeTree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
predTree = strokeTree.predict(X_test)
print (predTree [0:5])
print (y_test [0:5])
# Out:
# [1 0 0 1 0]
# 3885    1
# 2217    0
# 1902    0
# 3210    0
# 2021    0
# Name: stroke, dtype: int64

# %% [markdown]
# #### Evaluation & Visualization

# %%
print('\nClassification Report for Decision Tree Algorithm:')
print('\n', classification_report(y_test, predTree))
# Out:
# Classification Report for Decision Tree Algorithm:
#
#                precision    recall  f1-score   support
#
#            0       0.80      0.90      0.85       638
#            1       0.89      0.79      0.83       660
#
#     accuracy                           0.84      1298
#    macro avg       0.85      0.84      0.84      1298
# weighted avg       0.85      0.84      0.84      1298

# %%
viz_cm = confusion_matrix(y_test, predTree)
labels = ['Not Stroke (0)', 'Stroke (1)']
          
plt.figure(figsize=(8, 6))
sns.heatmap(viz_cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix for Decision Tree')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
import sklearn.tree as tree

print ("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, predTree))
tree.plot_tree(strokeTree)
plt.show()
# Out:
# DecisionTrees's Accuracy:  0.8412942989214176

# %%
from sklearn.tree import export_text
#Informasi tiap node dalam bentuk teks

tree_rules = export_text(strokeTree, feature_names=['gender', 'age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi', 'smoking_status'])
print(tree_rules)
# Out:
# |--- age <= 45.02
# |   |--- age <= 31.50
# |   |   |--- class: 0
# |   |--- age >  31.50
# |   |   |--- gender <= 0.80
# |   |   |   |--- gender <= 0.01
# |   |   |   |   |--- avg_glucose_level <= 99.26
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- avg_glucose_level >  99.26
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- gender >  0.01
# |   |   |   |   |--- class: 1
# |   |   |--- gender >  0.80
# |   |   |   |--- age <= 44.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- age >  44.50
# |   |   |   |   |--- avg_glucose_level <= 64.78
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- avg_glucose_level >  64.78
# |   |   |   |   |   |--- class: 0
# |--- age >  45.02
# |   |--- hypertension <= 0.00
# |   |   |--- heart_disease <= 0.00
# |   |   |   |--- age <= 68.01
# |   |   |   |   |--- bmi <= 25.54
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- bmi >  25.54
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- age >  68.01
# |   |   |   |   |--- smoking_status <= 0.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- smoking_status >  0.00
# |   |   |   |   |   |--- class: 1
# |   |   |--- heart_disease >  0.00
# |   |   |   |--- heart_disease <= 1.00
# |   |   |   |   |--- class: 1
# |   |   |   |--- heart_disease >  1.00
# |   |   |   |   |--- avg_glucose_level <= 103.48
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- avg_glucose_level >  103.48
# |   |   |   |   |   |--- class: 1
# |   |--- hypertension >  0.00
# |   |   |--- hypertension <= 1.00
# |   |   |   |--- class: 1
# |   |   |--- hypertension >  1.00
# |   |   |   |--- age <= 65.06
# |   |   |   |   |--- heart_disease <= 0.01
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- heart_disease >  0.01
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- age >  65.06
# |   |   |   |   |--- smoking_status <= 0.02
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- smoking_status >  0.02
# |   |   |   |   |   |--- class: 1

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(25, 12))
plot_tree(strokeTree, filled=True, feature_names=['gender', 'age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi', 'smoking_status'], 
          class_names=['Not Stroke', 'Stroke'], rounded=True, fontsize=10)
plt.show()

# %% [markdown]
# ---
# ### <div align="center">Algorithm Support Vector Machine</div>

# %% [markdown]
# #### Modeling

# %%
from sklearn import svm

# %%
clf = svm.SVC(kernel='linear')
clf.fit(X_train, y_train)

yhat = clf.predict(X_test)
yhat[0:5]
# Out:
# array([1, 1, 1, 1, 0], dtype=int64)

# %% [markdown]
# #### Evaluation

# %%
print('\nClassification Report for Support Vector Machine Algorithm:')
print('\n', classification_report(y_test, yhat))
# Out:
# Classification Report for Support Vector Machine Algorithm:
#
#                precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74       638
#            1       0.74      0.78      0.76       660
#
#     accuracy                           0.75      1298
#    macro avg       0.75      0.75      0.75      1298
# weighted avg       0.75      0.75      0.75      1298

# %%
print("SVM's Accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# SVM's Accuracy:  0.75115562403698

# %%
viz_cm = confusion_matrix(y_test, yhat)
labels = ['Not Stroke (0)', 'Stroke (1)']
          
plt.figure(figsize=(8, 6))
sns.heatmap(viz_cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix for SVM')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
print("Avg F1-score : %.4f" % f1_score(y_test, yhat, average="weighted"))
print("Jaccard_score : %.4f" % jaccard_score(y_test, yhat, average="micro"))
# Out:
# Avg F1-score : 0.7508
# Jaccard_score : 0.6015

# %% [markdown]
# ---
# ### <div align="center">Algorithm K-Nearest Neighbors Classification</div>

# %% [markdown]
# #### Modeling

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors = 5)

# %%
knn_model.fit(X_train, y_train)
knn_pred = knn_model.predict(X_test)

# %% [markdown]
# #### Evaluation

# %%
print('\nClassification Report for KNN:')
print('\n', classification_report(y_test, knn_pred))
# Out:
# Classification Report for KNN:
#
#                precision    recall  f1-score   support
#
#            0       0.95      0.78      0.86       638
#            1       0.82      0.96      0.89       660
#
#     accuracy                           0.87      1298
#    macro avg       0.89      0.87      0.87      1298
# weighted avg       0.89      0.87      0.87      1298

# %%
print("KNN's Accuracy: ", metrics.accuracy_score(y_test, knn_pred))
# Out:
# KNN's Accuracy:  0.8736517719568567

# %%
knn_cm = confusion_matrix(y_test, knn_pred)
labels = ['Not Stroke (0)', 'Stroke (1)']

plt.figure(figsize=(8, 6))
sns.heatmap(knn_cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix for KNN')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ---
# ### <div align="center">Comparation dari Tiap Algorithm yang dipakai</div>

# %%
# Classification Report Decision Tree
DT_precision = [0.80, 0.89]
DT_recalSl = [0.90, 0.79]
DT_f1 = [0.85, 0.83]
DT_accuracy = 0.84  

# Classification Report SVM
SVM_precision = [0.76, 0.74]
SVM_recall = [0.72, 0.78]
SVM_f1 = [0.74, 0.76]
SVM_accuracy = 0.75  

# Classification Report Decision Tree
KNN_precision = [0.95, 0.82]
KNN_recall = [0.78, 0.96]
KNN_f1 = [0.86, 0.89]
KNN_accuracy =  0.87

labels = ['Not Stroke (0)', 'Stroke (1)']

# %%
# Plotting precision
plt.figure(figsize=(14, 6))
bar_width = 0.3

bars_dt = plt.bar(np.arange(len(labels)), DT_precision, width=bar_width, label='Decision Tree', align='center')
bars_svm = plt.bar(np.arange(len(labels)) + bar_width, SVM_precision, width=bar_width, label='SVM', align='center')
bars_knn = plt.bar(np.arange(len(labels)) + 2*bar_width, KNN_precision, width=bar_width, label='KNN', align='center')

plt.xlabel('Classes')
plt.ylabel('Precision')
plt.title('Precision Comparison')
plt.xticks(np.arange(len(labels)) + bar_width, labels)

# Menambahkan persentase
for bars in [bars_dt, bars_svm, bars_knn]:
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2%}', ha='center', va='bottom')

plt.legend()
plt.ylim(0, 1.0)
plt.show()

# %%
# Plotting recall
plt.figure(figsize=(14, 6))
bar_width = 0.3

bars_dt = plt.bar(np.arange(len(labels)), DT_recall, width=bar_width, label='Decision Tree', align='center')
bars_svm = plt.bar(np.arange(len(labels)) + bar_width, SVM_recall, width=bar_width, label='SVM', align='center')
bars_knn = plt.bar(np.arange(len(labels)) + 2*bar_width, KNN_recall, width=bar_width, label='KNN', align='center')

plt.xlabel('Classes')
plt.ylabel('Recall')
plt.title('Recall Comparison')
plt.xticks(np.arange(len(labels)) + bar_width, labels)

# Menambahkan persentase
for bars in [bars_dt, bars_svm, bars_knn]:
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2%}', ha='center', va='bottom')

plt.legend()
plt.ylim(0, 1.0)
plt.show()

# %%
# Plotting F1-score
plt.figure(figsize=(14, 6))
bar_width = 0.3

bars_dt = plt.bar(np.arange(len(labels)), DT_f1, width=bar_width, label='Decision Tree', align='center')
bars_svm = plt.bar(np.arange(len(labels)) + bar_width, SVM_f1, width=bar_width, label='SVM', align='center')
bars_knn = plt.bar(np.arange(len(labels)) + 2*bar_width, KNN_f1, width=bar_width, label='KNN', align='center')

plt.xlabel('Classes')
plt.ylabel('F1-score')
plt.title('F1-score Comparison')
plt.xticks(np.arange(len(labels)) + bar_width, labels)

# Menambahkan persentase
for bars in [bars_dt, bars_svm, bars_knn]:
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2%}', ha='center', va='bottom')

plt.legend()
plt.ylim(0, 1.0)
plt.show()

# %%
# Plotting Accuracy
plt.figure(figsize=(8, 6))
accuracy_values = [DT_accuracy, SVM_accuracy, KNN_accuracy]
bars = plt.bar(['Decision Tree', 'SVM', 'KNN'], accuracy_values, color=['blue', 'orange', 'green'])
plt.ylim(0, 1.0)

# Menambahkan persentase
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2%}', ha='center', va='bottom')

plt.xlabel('\nAlgorithms')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### Test Prediction

# %%
coba = [[1.  ,  67.  ,   0.  ,   1.  , 228.69,  36.6 ,   0.]]

cobaDT = strokeTree.predict(coba)
print("Dengan menggunakan model Algorithm Decision Tree")
for prediction in cobaDT:
    if prediction == 0:
        print("Diprediksi pasien tidak menderita Stroke")
    else:
        print("Diprediksi pasien menderita Stroke")
# Out:
# Dengan menggunakan model Algorithm Decision Tree
# Diprediksi pasien menderita Stroke

# %%
coba = [[1.  ,  67.  ,   0.  ,   1.  , 228.69,  36.6 ,   0.]]

cobaSVM = clf.predict(coba)
print("Dengan menggunakan model Algorithm SVM")
for prediction in cobaSVM:
    if prediction == 0:
        print("Diprediksi pasien tidak menderita Stroke")
    else:
        print("Diprediksi pasien menderita Stroke")
# Out:
# Dengan menggunakan model Algorithm SVM
# Diprediksi pasien menderita Stroke

# %%
coba = [[1.  ,  67.  ,   0.  ,   1.  , 228.69,  36.6 ,   0.]]

cobaKNN = knn_model.predict(coba)
print("Dengan menggunakan model Algorithm KNN")
for prediction in cobaKNN:
    if prediction == 0:
        print("Diprediksi pasien tidak menderita Stroke")
    else:
        print("Diprediksi pasien menderita Stroke")
# Out:
# Dengan menggunakan model Algorithm KNN
# Diprediksi pasien menderita Stroke

# %% [markdown]
# #### Compare the prediction

# %%
compare = pd.DataFrame({'Stroke Actual': y_test, 'Predicted_DT': predTree, 
                        'Predicted_SVM': yhat, 'Predicted_KNN': knn_pred})

for column in compare:
    compare[column] = compare[column].map({0: 'Not Stroke', 1: 'Stroke'})
    
compare
# Out:
#      Stroke Actual Predicted_DT Predicted_SVM Predicted_KNN
# 3885        Stroke       Stroke        Stroke        Stroke
# 2217    Not Stroke   Not Stroke        Stroke    Not Stroke
# 1902    Not Stroke   Not Stroke        Stroke    Not Stroke
# 3210    Not Stroke       Stroke        Stroke        Stroke
# 2021    Not Stroke   Not Stroke    Not Stroke    Not Stroke
# ...            ...          ...           ...           ...
# 2318    Not Stroke       Stroke        Stroke    Not Stroke
# 6119        Stroke       Stroke        Stroke        Stroke
# 2592    Not Stroke   Not Stroke    Not Stroke        Stroke
# 1151    Not Stroke   Not Stroke    Not Stroke    Not Stroke
# 1895    Not Stroke   Not Stroke    Not Stroke    Not Stroke
#
# [1298 rows x 4 columns]

# %% [markdown]
# # NAIVE BAYES - CHRISTOPHER KENNETH DAVID

# %% [markdown]
# ## MODELING

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

nb_model = GaussianNB()

nb_model.fit(X_train, y_train)

y_pred = nb_model.predict(X_test)
# Out:
#                precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77       638
#            1       0.79      0.74      0.77       660
#
#     accuracy                           0.77      1298
#    macro avg       0.77      0.77      0.77      1298
# weighted avg       0.77      0.77      0.77      1298

# %% [markdown]
# ## Evaluation

# %%
accuracy = metrics.accuracy_score(y_test, y_pred)
precision = metrics.precision_score(y_test, y_pred)
recall = metrics.recall_score(y_test, y_pred)
f1 = metrics.f1_score(y_test, y_pred)

print('\n', classification_report(y_test, y_pred))
# Out:
#                precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77       638
#            1       0.79      0.74      0.77       660
#
#     accuracy                           0.77      1298
#    macro avg       0.77      0.77      0.77      1298
# weighted avg       0.77      0.77      0.77      1298

# %%
nb_cm = confusion_matrix(y_test, y_pred)
labels = ['Not Stroke (0)', 'Stroke (1)']
          
plt.figure(figsize=(8, 6))
sns.heatmap(nb_cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix for Naive Bayes')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Classification Report Decision Tree
DT_precision = [0.80, 0.89]
DT_recall = [0.90, 0.79]
DT_f1 = [0.85, 0.83]
DT_accuracy = 0.84  

# Classification Report SVM
SVM_precision = [0.76, 0.74]
SVM_recall = [0.72, 0.78]
SVM_f1 = [0.74, 0.76]
SVM_accuracy = 0.75  

# Classification Report Decision Tree
KNN_precision = [0.95, 0.82]
KNN_recall = [0.78, 0.96]
KNN_f1 = [0.86, 0.89]
KNN_accuracy =  0.87

# Classification Report Naive Bayes
NB_precision = [0.75, 0.79]
NB_recall = [0.80, 0.74]
NB_f1 = [0.86, 0.89]
NB_acc = 0.77

labels = ['Not Stroke (0)', 'Stroke (1)']

# %%
# Plotting precision
plt.figure(figsize=(14, 6))
bar_width = 0.1

bars_dt = plt.bar(np.arange(len(labels)), DT_precision, width=bar_width, label='Decision Tree', align='center')
bars_svm = plt.bar(np.arange(len(labels)) + bar_width, SVM_precision, width=bar_width, label='SVM', align='center')
bars_knn = plt.bar(np.arange(len(labels)) + 2*bar_width, KNN_precision, width=bar_width, label='KNN', align='center')
bars_nb = plt.bar(np.arange(len(labels)) + 3*bar_width, NB_precision, width=bar_width, label='NB', align='center')

plt.xlabel('Classes')
plt.ylabel('Precision')
plt.title('Precision Comparison')
plt.xticks(np.arange(len(labels)) + bar_width, labels)

# Menambahkan persentase
for bars in [bars_dt, bars_svm, bars_knn, bars_nb]:
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2%}', ha='center', va='bottom')

plt.legend()
plt.ylim(0, 1.0)
plt.show()

# %%
# Plotting recall
plt.figure(figsize=(14, 6))
bar_width = 0.1

bars_dt = plt.bar(np.arange(len(labels)), DT_recall, width=bar_width, label='Decision Tree', align='center')
bars_svm = plt.bar(np.arange(len(labels)) + bar_width, SVM_recall, width=bar_width, label='SVM', align='center')
bars_knn = plt.bar(np.arange(len(labels)) + 2*bar_width, KNN_recall, width=bar_width, label='KNN', align='center')
bars_nb = plt.bar(np.arange(len(labels)) + 3*bar_width, NB_recall, width=bar_width, label='NB', align='center')

plt.xlabel('Classes')
plt.ylabel('Recall')
plt.title('Recall Comparison')
plt.xticks(np.arange(len(labels)) + bar_width, labels)

# Menambahkan persentase
for bars in [bars_dt, bars_svm, bars_knn, bars_nb]:
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2%}', ha='center', va='bottom')

plt.legend()
plt.ylim(0, 1.0)
plt.show()

# %%
# Plotting F1-score
plt.figure(figsize=(14, 6))
bar_width = 0.1

bars_dt = plt.bar(np.arange(len(labels)), DT_f1, width=bar_width, label='Decision Tree', align='center')
bars_svm = plt.bar(np.arange(len(labels)) + bar_width, SVM_f1, width=bar_width, label='SVM', align='center')
bars_knn = plt.bar(np.arange(len(labels)) + 2*bar_width, KNN_f1, width=bar_width, label='KNN', align='center')
bars_nb = plt.bar(np.arange(len(labels)) + 3*bar_width, NB_f1, width=bar_width, label='NB', align='center')

plt.xlabel('Classes')
plt.ylabel('F1-score')
plt.title('F1-score Comparison')
plt.xticks(np.arange(len(labels)) + bar_width, labels)

# Menambahkan persentase
for bars in [bars_dt, bars_svm, bars_knn, bars_nb]:
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2%}', ha='center', va='bottom')

plt.legend()
plt.ylim(0, 1.0)
plt.show()

# %%
# Plotting Accuracy
plt.figure(figsize=(8, 6))
accuracy_values = [DT_accuracy, SVM_accuracy, KNN_accuracy, NB_acc]
bars = plt.bar(['Decision Tree', 'SVM', 'KNN', 'NB'], accuracy_values, color=['blue', 'yellow', 'green','red'])
plt.ylim(0, 1.0)

# Menambahkan persentase
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2%}', ha='center', va='bottom')

plt.xlabel('\nAlgorithms')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison')
plt.show()

# %%
coba = [[1.  ,  67.  ,   0.  ,   1.  , 228.69,  36.6 ,   0.]]

cobaNB = nb_model.predict(coba)
print("Dengan menggunakan model Algorithm Naive Bayes")
for prediction in cobaNB:
    if prediction == 0:
        print("Diprediksi pasien tidak menderita Stroke")
    else:
        print("Diprediksi pasien menderita Stroke")
# Out:
# Dengan menggunakan model Algorithm Naive Bayes
# Diprediksi pasien menderita Stroke

# %%
compare = pd.DataFrame({'Stroke Actual': y_test, 'Predicted_DT': predTree, 
                        'Predicted_SVM': yhat, 'Predicted_KNN': knn_pred, 'Predicted_NB':y_pred})

for column in compare:
    compare[column] = compare[column].map({0: 'Not Stroke', 1: 'Stroke'})
    
compare
# Out:
#      Stroke Actual Predicted_DT Predicted_SVM Predicted_KNN Predicted_NB
# 3885        Stroke       Stroke        Stroke        Stroke       Stroke
# 2217    Not Stroke   Not Stroke        Stroke    Not Stroke   Not Stroke
# 1902    Not Stroke   Not Stroke        Stroke    Not Stroke       Stroke
# 3210    Not Stroke       Stroke        Stroke        Stroke       Stroke
# 2021    Not Stroke   Not Stroke    Not Stroke    Not Stroke   Not Stroke
# ...            ...          ...           ...           ...          ...
# 2318    Not Stroke       Stroke        Stroke    Not Stroke       Stroke
# 6119        Stroke       Stroke        Stroke        Stroke       Stroke
# 2592    Not Stroke   Not Stroke    Not Stroke        Stroke   Not Stroke
# 1151    Not Stroke   Not Stroke    Not Stroke    Not Stroke   Not Stroke
# 1895    Not Stroke   Not Stroke    Not Stroke    Not Stroke   Not Stroke
#
# [1298 rows x 5 columns]
